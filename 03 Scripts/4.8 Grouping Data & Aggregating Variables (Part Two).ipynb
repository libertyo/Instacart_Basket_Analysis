# %% [markdown]
# # Achievement 4, Task 8

# %%
#import libraries 
import numpy as np 
import pandas as pd 
import os

# %%
path = r'/Users/libertyonia/Documents/Instacart Basket Analysis'

# %%
#import ords_prods_merge dataframe 
ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merge_4.7'))

# %%
ords_prods_merge.head(1)
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2398795        1    prior             2                  3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  7                    15.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          1         Soda        77              7     9.0   both
#
#      price_range_loc     busiest_day  busiest_days busiest_period_of_day
# 0  Mid-range product  Regularly busy  Slowest days         Average hours

# %% [markdown]
# # Question 2
# In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
#group by department_id and aggregate order_number by mean 
ords_prods_merge.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.559358
# 2                18.413176
# 3                18.279600
# 4                18.915890
# 5                16.497751
# 6                17.609390
# 7                18.303975
# 8                16.383301
# 9                17.022963
# 10               21.227447
# 11               17.311768
# 12               16.953613
# 13               17.727470
# 14               17.898097
# 15               17.290123
# 16               18.757796
# 17               16.808683
# 18               20.336389
# 19               18.258620
# 20               17.578959
# 21               23.644477

# %% [markdown]
# # Question 3
# #### Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.
#
# The subset only had department_id 4, 7 , 13, 14, 16, 17, 19, and 20. This means that these department_ids were the only ones in the first 1,000,000 rows. The means for department_ids 4,7,13,14,16,17, and 19 are slightly different in subset compared to the full ords_prods_merge dataframe.

# %% [markdown]
# # Question 4
# Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
#Assign new column max_order 
#Group the user_id column 
#Apply the transform function on the "order_number" column with np.max argument 
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#Create a flag that assigns a "loyalty" label to a used ID based on its max order value 
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
#Create a flag that assigns a "loyalty" label to a used ID based on its max order value
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
#Create a flag that assigns a "loyalty" label to a used ID based on its max order value
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#count values in new loyalty_flag column with N/A values 
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# Name: loyalty_flag, dtype: int64

# %%
#count values in new loyalty_flag column without drop N/A values
#same as with N/A values, because there are no N/A values
ords_prods_merge['loyalty_flag'].value_counts(dropna = True)
# Out:
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# Name: loyalty_flag, dtype: int64

# %%
#Limit the head() function to include columns that you only want to check 
ords_prods_merge[['user_id','loyalty_flag','order_number','max_order']].head(60)
# Out:
#     user_id      loyalty_flag  order_number  max_order
# 0         1      New customer             2         10
# 1         1      New customer             3         10
# 2         1      New customer             4         10
# 3         1      New customer             5         10
# 4         1      New customer             6         10
# 5         1      New customer             7         10
# 6         1      New customer             8         10
# 7         1      New customer             9         10
# 8         1      New customer            10         10
# 9        15  Regular customer            15         22
# 10       15  Regular customer            17         22
# 11       15  Regular customer            18         22
# 12       15  Regular customer            21         22
# 13       15  Regular customer            22         22
# 14       19      New customer             2          9
# 15       19      New customer             5          9
# ...

# %%
#Add the summary statistics for the customer loyalty flag
ords_prods_merge.groupby('loyalty_flag').agg({'max_order': ['mean']})
# Out:
#                   max_order
#                        mean
# loyalty_flag
# Loyal customer    64.063418
# New customer       6.758699
# Regular customer  23.587759

# %% [markdown]
# # Question 6
# The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
#
# - If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# - If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
#group by user_id 
#average prices using .transform(np.average) 
#name new column as average_spending
ords_prods_merge['average_spending'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.average)

# %%
ords_prods_merge[['user_id','prices','average_spending']].head(20)
# Out:
#     user_id  prices  average_spending
# 0         1     9.0          6.372222
# 1         1     9.0          6.372222
# 2         1     9.0          6.372222
# 3         1     9.0          6.372222
# 4         1     9.0          6.372222
# 5         1     9.0          6.372222
# 6         1     9.0          6.372222
# 7         1     9.0          6.372222
# 8         1     9.0          6.372222
# 9        15     9.0          3.994118
# 10       15     9.0          3.994118
# 11       15     9.0          3.994118
# 12       15     9.0          3.994118
# 13       15     9.0          3.994118
# 14       19     9.0          8.464535
# 15       19     9.0          8.464535
# 16       19     9.0          8.464535
# 17       21     9.0          6.987500
# 18       31     9.0          8.203147
# 19       31     9.0          8.203147

# %%
#If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
ords_prods_merge.loc[ords_prods_merge['average_spending'] < 10, 'spending_flag'] = 'Low spender'

# %%
#If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”
ords_prods_merge.loc[ords_prods_merge['average_spending'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge[['user_id','prices','average_spending','spending_flag']].head(20)
# Out:
#     user_id  prices  average_spending spending_flag
# 0         1     9.0          6.372222   Low spender
# 1         1     9.0          6.372222   Low spender
# 2         1     9.0          6.372222   Low spender
# 3         1     9.0          6.372222   Low spender
# 4         1     9.0          6.372222   Low spender
# 5         1     9.0          6.372222   Low spender
# 6         1     9.0          6.372222   Low spender
# 7         1     9.0          6.372222   Low spender
# 8         1     9.0          6.372222   Low spender
# 9        15     9.0          3.994118   Low spender
# 10       15     9.0          3.994118   Low spender
# 11       15     9.0          3.994118   Low spender
# 12       15     9.0          3.994118   Low spender
# 13       15     9.0          3.994118   Low spender
# 14       19     9.0          8.464535   Low spender
# 15       19     9.0          8.464535   Low spender
# 16       19     9.0          8.464535   Low spender
# ...

# %%
#value counts of "spending_flag" with N/A values
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     29730516
# High spender      598247
# Name: spending_flag, dtype: int64

# %%
#value counts of "spending_flag" without N/A values 
#same as with N/A values, because there are no N/A values
ords_prods_merge['spending_flag'].value_counts(dropna = True)
# Out:
# Low spender     29730516
# High spender      598247
# Name: spending_flag, dtype: int64

# %% [markdown]
# # Question 7
# In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# - If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# - If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# - If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
#group by user_id 
#median of days_since_prior_order
#new label median_dspo
ords_prods_merge['median_dspo'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head(2)
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2398795        1    prior             2                  3
# 1    473747        1    prior             3                  3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  7                    15.0         196                  1
# 1                 12                    21.0         196                  1
#
#    reordered  ... _merge    price_range_loc     busiest_day  busiest_days  \
# 0          1  ...   both  Mid-range product  Regularly busy  Slowest days
# 1          1  ...   both  Mid-range product  Regularly busy  Slowest days
#
#   busiest_period_of_day max_order  loyalty_flag average_spending  \
# 0         Average hours        10  New customer         6.372222
# 1         Average hours        10  New customer         6.372222
#
#   spending_flag  median_dspo
# 0   Low spender         20.5
# 1   Low spender         20.5
#
# [2 rows x 24 columns]

# %%
#If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
ords_prods_merge.loc[ords_prods_merge['median_dspo'] > 20, 'order_behavior'] = "Non-frequent customer"

# %%
#If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
ords_prods_merge.loc[(ords_prods_merge['median_dspo'] > 10) & (ords_prods_merge['median_dspo'] <= 20), 'order_behavior'] = "Regular customer"

# %%
#If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”
ords_prods_merge.loc[ords_prods_merge['median_dspo'] <= 10, 'order_behavior'] = "Frequent customer"

# %%
ords_prods_merge[['user_id','median_dspo','order_behavior']].head(60)
# Out:
#     user_id  median_dspo         order_behavior
# 0         1         20.5  Non-frequent customer
# 1         1         20.5  Non-frequent customer
# 2         1         20.5  Non-frequent customer
# 3         1         20.5  Non-frequent customer
# 4         1         20.5  Non-frequent customer
# 5         1         20.5  Non-frequent customer
# 6         1         20.5  Non-frequent customer
# 7         1         20.5  Non-frequent customer
# 8         1         20.5  Non-frequent customer
# 9        15         10.0      Frequent customer
# 10       15         10.0      Frequent customer
# 11       15         10.0      Frequent customer
# 12       15         10.0      Frequent customer
# 13       15         10.0      Frequent customer
# 14       19          6.0      Frequent customer
# 15       19          6.0      Frequent customer
# 16       19          6.0      Frequent customer
# 17       21          7.5      Frequent customer
# 18       31          6.0      Frequent customer
# ...

# %%
#count the frequency of column 'order_behavior' with N/A values
ords_prods_merge['order_behavior'].value_counts(dropna = False)
# Out:
# Frequent customer        20675290
# Regular customer          6594542
# Non-frequent customer     3058931
# Name: order_behavior, dtype: int64

# %%
#count the frequency of column 'order_behavior' without N/A values
#same as with N/A values, because there are no N/A values
ords_prods_merge['order_behavior'].value_counts(dropna = True)
# Out:
# Frequent customer        20675290
# Regular customer          6594542
# Non-frequent customer     3058931
# Name: order_behavior, dtype: int64

# %% [markdown]
# # Question 9
# Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
ords_prods_merge.head(2)
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2398795        1    prior             2                  3
# 1    473747        1    prior             3                  3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  7                    15.0         196                  1
# 1                 12                    21.0         196                  1
#
#    reordered  ...    price_range_loc     busiest_day  busiest_days  \
# 0          1  ...  Mid-range product  Regularly busy  Slowest days
# 1          1  ...  Mid-range product  Regularly busy  Slowest days
#
#    busiest_period_of_day max_order  loyalty_flag average_spending  \
# 0          Average hours        10  New customer         6.372222
# 1          Average hours        10  New customer         6.372222
#
#   spending_flag median_dspo         order_behavior
# 0   Low spender        20.5  Non-frequent customer
# ...

# %%
#Remove the outlier in the prices column in ords_prods_merge 
ords_prods_merge.loc[ords_prods_merge['prices'] > 100, 'prices'] = np.nan

# %%
#Export dataframe
ords_prods_merge.to_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merge_4.8.pkl'))
