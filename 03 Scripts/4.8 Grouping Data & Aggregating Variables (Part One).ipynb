# %% [markdown]
# # 4.8 Following reading

# %%
#Import libraries 
import numpy as np 
import pandas as pd 
import os

# %%
#path to project folder 
path = r'/Users/libertyonia/Documents/Instacart Basket Analysis'

# %%
#import updated ords_prods_merge dataframe 
ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merge_4.7'))

# %%
#columns of ords_prods_merge
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  order_day_of_week  \
# 0   2398795        1    prior             2                  3
# 1    473747        1    prior             3                  3
# 2   2254736        1    prior             4                  4
# 3    431534        1    prior             5                  4
# 4   3367565        1    prior             6                  2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  7                    15.0         196                  1
# 1                 12                    21.0         196                  1
# 2                  7                    29.0         196                  1
# 3                 15                    28.0         196                  1
# 4                  7                    19.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (30328763, 19)

# %%
#create subset of 1,000,000 rows 
df = ords_prods_merge[:1000000]

# %% [markdown]
# # Grouping Data with pandas

# %%
#group by product name
df.groupby('product_name')

# %% [markdown]
# # Aggregating Data with agg()

# %%
#group by the department_id 
#aggregate by order_number and return the mean 
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                19.765396
# 7                18.575283
# 13               18.950838
# 14               20.460336
# 16               20.262396
# 17               12.646785
# 19               20.168036
# 20               18.808671

# %%
#multiple aggregations min, max, mean 
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                19.765396   2  99
# 7                18.575283   2  99
# 13               18.950838   2  99
# 14               20.460336   2  99
# 16               20.262396   2  99
# 17               12.646785   2  98
# 19               20.168036   2  99
# 20               18.808671   2  99

# %% [markdown]
# # Aggregating data with transform()

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2398795        1    prior             2                  3
# 1     473747        1    prior             3                  3
# 2    2254736        1    prior             4                  4
# 3     431534        1    prior             5                  4
# 4    3367565        1    prior             6                  2
# 5     550135        1    prior             7                  1
# 6    3108588        1    prior             8                  1
# 7    2295261        1    prior             9                  1
# 8    2550362        1    prior            10                  4
# 9    2968173       15    prior            15                  1
# 10   1870022       15    prior            17                  2
# 11   1911383       15    prior            18                  2
# 12   2715276       15    prior            21                  1
# 13    487368       15    prior            22                  1
# ...

# %%
#python not to assign any options regarding the max number of rows to display 
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  order_day_of_week  \
# 0    2398795        1    prior             2                  3
# 1     473747        1    prior             3                  3
# 2    2254736        1    prior             4                  4
# 3     431534        1    prior             5                  4
# 4    3367565        1    prior             6                  2
# 5     550135        1    prior             7                  1
# 6    3108588        1    prior             8                  1
# 7    2295261        1    prior             9                  1
# 8    2550362        1    prior            10                  4
# 9    2968173       15    prior            15                  1
# 10   1870022       15    prior            17                  2
# 11   1911383       15    prior            18                  2
# 12   2715276       15    prior            21                  1
# 13    487368       15    prior            22                  1
# ...

# %% [markdown]
# # Deriving Columns with loc()

# %%
# Create a flag that assigns a “loyalty” label to a user ID based on its corresponding max order value.
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#count values in new loyalty_flag column 
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# Name: loyalty_flag, dtype: int64

# %%
#Limit the head() function to include columns that you only want to check 
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             2
# 1         1      New customer             3
# 2         1      New customer             4
# 3         1      New customer             5
# 4         1      New customer             6
# 5         1      New customer             7
# 6         1      New customer             8
# 7         1      New customer             9
# 8         1      New customer            10
# 9        15  Regular customer            15
# 10       15  Regular customer            17
# 11       15  Regular customer            18
# 12       15  Regular customer            21
# 13       15  Regular customer            22
# 14       19      New customer             2
# 15       19      New customer             5
# 16       19      New customer             7
# 17       21  Regular customer            10
# 18       31  Regular customer            10
# 19       31  Regular customer            17
# ...
